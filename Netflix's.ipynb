# %%
import pandas as pd

# %%
df = pd.read_csv("Netflix Dataset.csv")

# %%
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df.shape
# Out:
# (7789, 11)

# %%
df.shape[0]
# Out:
# 7789

# %%
df.shape[1]
# Out:
# 11

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
df[df.duplicated ()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
df[df["Title"]=="Houes of Cards"][["Show_Id","Director"]]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Director]
# Index: []

# %%
df[df["Title"].str.contains("Houes of Cards")][["Show_Id", "Director"]]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Director]
# Index: []

# %%
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data['Date_N'] = pd.to_datetime(data['Release_Date'], format = 'mixed')

# %%
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data.head()
#
# NameError: name 'data' is not defined

# %%
df["Release_Date"].head(2)
# Out:
# 0      August 14, 2020
# 1    December 23, 2016
# Name: Release_Date, dtype: object

# %%
df["N_Date"] = pd.to_datetime(df["Release_Date"], format="mixed")

# %%
df["N_Date"].dt.year.Value_counts().head(10).plot(kind="barn")

# %%
df[(df["Category"]=="TV show")&(df["Category"]=="India")]["Title"].sample(0)
# Out:
# Series([], Name: Title, dtype: object)

# %%
(df["Category"]=="TV Show") & (df["Category"]=="India").sample(2)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Name: Category, Length: 7789, dtype: bool

# %%
df["Director"].value_counts()
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
#                           ..
# Lucien Jean-Baptiste       1
# Jason Krawczyk             1
# Quinn Lasher               1
# Elle Callahan              1
# Sam Dunn                   1
# Name: count, Length: 4050, dtype: int64

# %%
df[(df["Category"]=="Movie")&(df["Type"]=="Comedies ")| (df["Country"]=="United Kingdom")]
# Out:
#      Show_Id Category                   Title           Director  \
# 19       s20    Movie                     '89                NaN
# 58       s59  TV Show             100% Hotter                NaN
# 82       s83    Movie     2036 Origin Unknown      Hasraf Dulull
# 85       s86  TV Show                21 Again                NaN
# 93       s94    Movie       27: Gone Too Soon  Simon Napier-Bell
# ...      ...      ...                     ...                ...
# 7670   s7669  TV Show  World War II in Colour                NaN
# 7671   s7670  TV Show  World's Busiest Cities                NaN
# 7688   s7687    Movie  XV: Beyond the Tryline   Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu        James Brown
# 7740   s7739  TV Show         Young Wallander                NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %%
df[df["Cast"]=="Tom Cruise"]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, N_Date]
# Index: []

# %%
df[df["Cast"].fillna("").str.contains ("Tom Cruise")]["Title"]
# Out:
# 3860    Magnolia
# 5071    Rain Man
# Name: Title, dtype: object

# %%
df["Rating"].unique ()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
df["Rating"].nunique()
# Out:
# 14

# %%
df[
    (df["Category"] == "Movie") &
    (df["Rating"] == "TV-14") &
    (df["Country"] == "Canada")
].shape[0]
# Out:
# 11

# %%
df[
    (df["Category"]=="TV Show")&
    (df["Rating"]=="R")&
    (df[
